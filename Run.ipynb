# %%
from Start_prog import *

# %%
TreeMassmatrix()[0]
# Out:
# ⎡                 2                                2         2 __
# ⎢         1.5⋅Z₁⋅ν                        0.75⋅Z₆⋅ν  + 0.75⋅ν ⋅Z₆
# ⎢
# ⎢           2         2 __            2           2            2         2 __
# ⎢  0.75⋅Z₆⋅ν  + 0.75⋅ν ⋅Z₆    0.5⋅Z₃⋅ν  + 0.5⋅Z₄⋅ν  + 0.25⋅Z₅⋅ν  + 0.25⋅ν ⋅Z₅
# ⎢
# ⎢           2           2 __                       2           2 __
# ⎣0.75⋅ⅈ⋅Z₆⋅ν  - 0.75⋅ⅈ⋅ν ⋅Z₆            0.25⋅ⅈ⋅Z₅⋅ν  - 0.25⋅ⅈ⋅ν ⋅Z₅
#
#                       2           2 __          ⎤
#            0.75⋅ⅈ⋅Z₆⋅ν  - 0.75⋅ⅈ⋅ν ⋅Z₆          ⎥
#                                                 ⎥
#                       2           2 __          ⎥
#            0.25⋅ⅈ⋅Z₅⋅ν  - 0.25⋅ⅈ⋅ν ⋅Z₅          ⎥
#                                                 ⎥
#          2           2            2         2 __⎥
#  0.5⋅Z₃⋅ν  + 0.5⋅Z₄⋅ν  - 0.25⋅Z₅⋅ν  - 0.25⋅ν ⋅Z₅⎦

# %%
TreeMassmatrix()[0] + LoopMassMatrix()
# Out:
# ⎡
# ⎢
# ⎢        2     2  2 ⎛            ⎛   μ²  ⎞    ⎞      ⎛     ⎛        ⎛   μ²  ⎞⎞
# ⎢1.5⋅Z₁⋅ν  + κ₁ ⋅ν ⋅⎜2⋅ξ₁ + 2⋅log⎜───────⎟ + 3⎟ + κ₁⋅⎜2⋅μ²⋅⎜ξ₁ + log⎜───────⎟⎟
# ⎢                   ⎝            ⎝Λ_WG__2⎠    ⎠      ⎝     ⎝        ⎝Λ_WG__2⎠⎠
# ⎢
# ⎢
# ⎢                          2  2 ⎛ ⅈ⋅θ    -ⅈ⋅θ⎞ ⎛            ⎛  μ²ₜ  ⎞    ⎞
# ⎢                        κ₂ ⋅ν ⋅⎝ℯ    + ℯ    ⎠⋅⎜2⋅ξ₂ + 2⋅log⎜───────⎟ + 3⎟⋅sin
# ⎢                    2                         ⎝            ⎝Λ_WG__2⎠    ⎠
# ⎢           0.75⋅Z₆⋅ν  + ─────────────────────────────────────────────────────
# ⎢                                                       2
# ⎢
# ⎢
# ⎢                         2  2 ⎛   ⅈ⋅θ    -ⅈ⋅θ⎞ ⎛            ⎛  μ²ₜ  ⎞    ⎞
# ⎢                     ⅈ⋅κ₂ ⋅ν ⋅⎝- ℯ    + ℯ    ⎠⋅⎜2⋅ξ₂ + 2⋅log⎜───────⎟ + 3⎟⋅si
# ⎢                 2                             ⎝            ⎝Λ_WG__2⎠    ⎠
# ⎢      0.75⋅ⅈ⋅Z₆⋅ν  + ────────────────────────────────────────────────────────
# ...

# %%
# Out:
#         2           2           2         2  2            2  2    ⎛   μ²  ⎞         2  2                               ⎛   μ²
# 1.5⋅Z₁⋅ν  + 1.0⋅Z₃⋅ν  + 1.0⋅Z₄⋅ν  + 2.0⋅κ₁ ⋅ν ⋅ξ₁ + 2.0⋅κ₁ ⋅ν ⋅log⎜───────⎟ + 3.0⋅κ₁ ⋅ν  + 6.0⋅κ₁⋅μ²⋅ξ₁ + 6.0⋅κ₁⋅μ²⋅log⎜─────
#                                                                   ⎝Λ_WG__2⎠                                            ⎝Λ_WG_
#
#   ⎞                     2  2       2            2  2    ⎛  μ²ₜ  ⎞    2            2  2    2                       2
# ──⎟ + 3.0⋅κ₁⋅μ² + 2.0⋅κ₂ ⋅ν ⋅ξ₂⋅cos (β) + 2.0⋅κ₂ ⋅ν ⋅log⎜───────⎟⋅cos (β) + 3.0⋅κ₂ ⋅ν ⋅cos (β) - 2.0⋅κ₂⋅μ²ₜ⋅ξ₂⋅cos (β) + 4.0⋅
# _2⎠                                                     ⎝Λ_WG__2⎠
#
#                           ⎛  μ²ₜ  ⎞    2                    ⎛  μ²ₜ  ⎞             2
# κ₂⋅μ²ₜ⋅ξ₂ - 2.0⋅κ₂⋅μ²ₜ⋅log⎜───────⎟⋅cos (β) + 4.0⋅κ₂⋅μ²ₜ⋅log⎜───────⎟ - κ₂⋅μ²ₜ⋅cos (β) + 2.0⋅κ₂⋅μ²ₜ
#                           ⎝Λ_WG__2⎠                         ⎝Λ_WG__2⎠

# %%
ChargedLoopMatrix() + TreeMassmatrix()[2]
# Out:
# ⎡    2
# ⎢Z₃⋅ν       ⎛     ⎛        ⎛   μ²  ⎞⎞     ⎞      ⎛      ⎛        ⎛  μ²ₜ  ⎞⎞
# ⎢───── + κ₁⋅⎜2⋅μ²⋅⎜ξ₁ + log⎜───────⎟⎟ + μ²⎟ + κ₂⋅⎜2⋅μ²ₜ⋅⎜ξ₂ + log⎜───────⎟⎟ +
# ⎣  2        ⎝     ⎝        ⎝Λ_WG__2⎠⎠     ⎠      ⎝      ⎝        ⎝Λ_WG__2⎠⎠
#
#             ⎤
#    ⎞    2   ⎥
# μ²ₜ⎟⋅cos (β)⎥
#    ⎠        ⎦

# %%
ZtoLambda(1)
# Out:
#           4                4              2       2              2       2
# 1.0⋅λ₁⋅cos (β) + 1.0⋅λ₂⋅sin (β) + 2⋅λ₃⋅sin (β)⋅cos (β) + 2⋅λ₄⋅sin (β)⋅cos (β)
#
#           2⋅ⅈ⋅θ    2       2              -2⋅ⅈ⋅θ    2       2
# + 1.0⋅λ₅⋅ℯ     ⋅sin (β)⋅cos (β) + 1.0⋅λ₅⋅ℯ      ⋅sin (β)⋅cos (β)

# %%
TreeMassmatrix()[0]
# Out:
# ⎡                 2                                2         2 __
# ⎢         1.5⋅Z₁⋅ν                        0.75⋅Z₆⋅ν  + 0.75⋅ν ⋅Z₆
# ⎢
# ⎢           2         2 __            2           2            2         2 __
# ⎢  0.75⋅Z₆⋅ν  + 0.75⋅ν ⋅Z₆    0.5⋅Z₃⋅ν  + 0.5⋅Z₄⋅ν  + 0.25⋅Z₅⋅ν  + 0.25⋅ν ⋅Z₅
# ⎢
# ⎢           2           2 __                       2           2 __
# ⎣0.75⋅ⅈ⋅Z₆⋅ν  - 0.75⋅ⅈ⋅ν ⋅Z₆            0.25⋅ⅈ⋅Z₅⋅ν  - 0.25⋅ⅈ⋅ν ⋅Z₅
#
#                       2           2 __          ⎤
#            0.75⋅ⅈ⋅Z₆⋅ν  - 0.75⋅ⅈ⋅ν ⋅Z₆          ⎥
#                                                 ⎥
#                       2           2 __          ⎥
#            0.25⋅ⅈ⋅Z₅⋅ν  - 0.25⋅ⅈ⋅ν ⋅Z₅          ⎥
#                                                 ⎥
#          2           2            2         2 __⎥
#  0.5⋅Z₃⋅ν  + 0.5⋅Z₄⋅ν  - 0.25⋅Z₅⋅ν  - 0.25⋅ν ⋅Z₅⎦

# %%
Treetadpole()
# Out:
# ⎛        3           3         3 __             3           3 __   ⎞
# ⎝0.5⋅Z₁⋅ν , 0.25⋅Z₆⋅ν  + 0.25⋅ν ⋅Z₆, 0.25⋅ⅈ⋅Z₆⋅ν  - 0.25⋅ⅈ⋅ν ⋅Z₆, 0⎠

# %%
OneLoopTadPole()
# Out:
# ⎛
# ⎜        3        ⎛     ⎛        ⎛   μ²  ⎞⎞     ⎞        ⎛      ⎛        ⎛  μ²
# ⎜0.5⋅Z₁⋅ν  + κ₁⋅ν⋅⎜2⋅μ²⋅⎜ξ₁ + log⎜───────⎟⎟ + μ²⎟ + κ₂⋅ν⋅⎜2⋅μ²ₜ⋅⎜ξ₂ + log⎜────
# ⎝                 ⎝     ⎝        ⎝Λ_WG__2⎠⎠     ⎠        ⎝      ⎝        ⎝Λ_WG
#
#
# ₜ  ⎞⎞      ⎞    2              3         3 __   ⎛      ⎛        ⎛  μ²ₜ  ⎞⎞
# ───⎟⎟ + μ²ₜ⎟⋅sin (β), 0.25⋅Z₆⋅ν  + 0.25⋅ν ⋅Z₆ + ⎜2⋅μ²ₜ⋅⎜ξ₂ + log⎜───────⎟⎟ + μ
# __2⎠⎠      ⎠                                    ⎝      ⎝        ⎝Λ_WG__2⎠⎠
#
#     ⎛      ⅈ⋅θ                       -ⅈ⋅θ              ⎞
#   ⎞ ⎜κ₂⋅ν⋅ℯ   ⋅sin(β)⋅cos(β)   κ₂⋅ν⋅ℯ    ⋅sin(β)⋅cos(β)⎟             3
# ²ₜ⎟⋅⎜─────────────────────── + ────────────────────────⎟, 0.25⋅ⅈ⋅Z₆⋅ν  - 0.25⋅
#   ⎠ ⎝           2                         2            ⎠
#
#                                             ⎛          ⅈ⋅θ
#    3 __   ⎛      ⎛        ⎛  μ²ₜ  ⎞⎞      ⎞ ⎜  ⅈ⋅κ₂⋅ν⋅ℯ   ⋅sin(β)⋅cos(β)   ⅈ⋅κ
# ⅈ⋅ν ⋅Z₆ + ⎜2⋅μ²ₜ⋅⎜ξ₂ + log⎜───────⎟⎟ + μ²ₜ⎟⋅⎜- ───────────────────────── + ───
# ...
